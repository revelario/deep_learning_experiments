# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import sys
from IPython.display import display, Image
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import OneHotEncoder
import pickle
import time
## cPicklne no worky in Python3
#from six.moves import cPickle as pickle
from six.moves import range

# Config the matlotlib backend as plotting inline in IPython
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf

# %%
def load_CIFAR_batch(filename):
  """ load single batch of cifar """
  with open(filename, 'rb') as f:
    datadict = pickle.load(f, encoding='latin')
    X = zero_center_pixels(datadict['data'])
    Y = datadict['labels']
    X = X.reshape(10000, 3, 32, 32).transpose(0,2,3,1).astype("float32")
    Y = LabelBinarizer().fit_transform(np.array(Y)) 
    return X, Y

# %%
def load_CIFAR10(ROOT):
  """ load all of cifar """
  xs = []
  ys = []
  for b in range(1,6):
    f = os.path.join(ROOT, 'data_batch_%d' % (b, ))
    X, Y = load_CIFAR_batch(f)
    xs.append(X)
    ys.append(Y)    
  Xtr = np.concatenate(xs)
  Ytr = np.concatenate(ys)
  del X, Y
  Xte, Yte = load_CIFAR_batch(os.path.join(ROOT, 'test_batch'))
  return Xtr, Ytr, Xte, Yte

# %%
def get_CIFAR10_data(num_training=50000, num_validation=0, num_test=10000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = './cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    X_train = X_train.astype("float32").copy()
    X_val = X_val.astype("float32").copy()
    x_test = X_test.astype("float32").copy()

    return X_train, y_train, X_val, y_val, X_test, y_test

# %%
def zero_center_pixels(data):
    scale = StandardScaler().fit(data)
    old_mean = scale.mean_.astype('float32')
    old_sigma = np.sqrt(scale.var_).astype('float32')
    return (data - old_mean) * 0.5 / old_sigma

# %%
train_dataset, train_labels, val_dataset, val_labels, test_dataset, test_labels = get_CIFAR10_data(50000, 0, 10000)
print('Train data shape: ', train_dataset.shape)
print('Train labels shape: ', train_labels.shape)
print('Validation data shape: ', val_dataset.shape)
print('Validation labels shape: ', val_labels.shape)
print('Test data shape: ', test_dataset.shape)
print('Test labels shape: ', test_labels.shape)
# Out:
# /Users/xx/anaconda/envs/tensorflow/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/xx/anaconda/envs/tensorflow/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/xx/anaconda/envs/tensorflow/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/xx/anaconda/envs/tensorflow/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/xx/anaconda/envs/tensorflow/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/xx/anaconda/envs/tensorflow/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# Train data shape:  (50000, 32, 32, 3)
# Train labels shape:  (50000, 10)
# Validation data shape:  (0, 32, 32, 3)
# Validation labels shape:  (0, 10)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000, 10)

# %%
'''
##  this code was repurposed from Week 7 Section Jupyter Notebook
## reshaping the data to 4D Tensor 

image_size = 32
num_labels = 10
num_channels = 3 # RGB

def reformat(dataset, labels):
    dataset = dataset.reshape((-1, image_size, image_size, num_channels)).astype(np.float32)
    labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
    return(dataset, labels)

train_dataset, train_labels = reformat(train_dataset, train_labels)
#valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
#print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
''';

# %% [markdown]
# ---
# - Step 5 -
# ============
# Convolutional Neural Nets
# ---------
#
# Now we turn to building a CNN using the architecture described in the TensorFlow website tutorial [Deep MNIST for Experts](https://www.tensorflow.org/versions/r0.11/tutorials/mnist/pros/index.html). It will be a small network with two convolutional layers, followed by one fully connected layer. We'll limit the depth of this model so that it will run fine on the CPU and give a more elaborate architecture below that you can experiment with. Most production CNNs run on GPUs because they require more computation power. You can also find this example explained in Chapter 5 of [First Contact with TensorFlow](http://www.jorditorres.org/first-contact-with-tensorflow/) and in Chapter 5 of "Getting started with TensorFlow" available on [Proquest through Hollis](http://proquest.safaribooksonline.com.ezp-prod1.hul.harvard.edu/book/programming/machine-learning/9781786468574)
#
# ### Other useful references
# There are also web books: Michael A. Nielsen, [Neural Networks and Deep Learning](http://neuralnetworksanddeeplearning.com/chap6.html) and Goodfellow-et-al [Deep Learning](http://www.deeplearningbook.org/) (which is a preprint, available in HTML). There is also [Colah's blog](http://colah.github.io/) that explains convolutions and has some impressive visualizations.
#
# If you want to experiment hands-on with convolutions, then download [the GIMP](https://www.gimp.org/downloads/) (if you don't already have it), load up some of your favourite images, and then go to Filters $\rightarrow$ Generic $\rightarrow$ Convolution Matrix.
# [Here](https://docs.gimp.org/en/plug-in-convmatrix.html) are some examples.
#
# ---

# %% [markdown]
# ### Choices to make in a CNN
# * convolution kernel dimensions: the patch size (e.g. 5x5)
# * stride length: 1, 2, something else
# * the padding, SAME or VALID
# * pooling: average or max pooling, pooling size
#
#
# To make the CNN, we will use two other `nn` functions in TensorFlow. The first is for the convolution itself, called [```tf.nn.conv2d()```](https://www.tensorflow.org/versions/r0.11/api_docs/python/nn.html#conv2d) . The function takes a 4D input tensor (hence the reformatting in the previous box), the weight variable and then both the stride and padding are specified as parameters.
#
# The second function is the pooling function, either [```tf.nn.max_pool```](https://www.tensorflow.org/versions/r0.11/api_docs/python/nn.html#max_pool) or [```tf.nn.avg_pool```](https://www.tensorflow.org/versions/r0.11/api_docs/python/nn.html#avg_pool). These functions take a 4D input tensor, along with the pooling size, the stride and the padding specified as parameters. We will show max_pool in the example.
#
# Note that between the parameters in convolution and the pooling, we have accumulated a number of hyper-parameters - this gives rise to a large number of options for tuning the best performing model, even without considering regularization/dropout and fully connected layers.
#
# We redefine the weight and bias functions as per the TensorFlow example.

# %%
## this code was repurposed from Week 7 Section Jupyter Notebook

def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
            / predictions.shape[0])

def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.01)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

# %%
## this code was repurposed from Week 7 Section Jupyter Notebook

# Re-define the function to include the keep probability
def run_session(num_epochs, name, k_prob=1.0):

    with tf.Session(graph=graph) as session:
        merged = tf.merge_all_summaries()  
        writer = tf.train.SummaryWriter("/tmp/tensorflowlogs", session.graph)
        tf.initialize_all_variables().run()
        print("Initialized")
        for epoch in range(num_epochs):
            offset = (epoch * batch_size) % (train_labels.shape[0] - batch_size)
            batch_data = train_dataset[offset:(offset + batch_size), :]
            batch_labels = train_labels[offset:(offset + batch_size), :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob : k_prob}
            _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
            if (epoch % 500 == 0):
                print("Minibatch loss at epoch {}: {}".format(epoch, l))
                print("Minibatch accuracy: {:.1f}".format(accuracy(predictions, batch_labels)))
                #print("Validation accuracy: {:.1f}".format(accuracy(valid_prediction.eval(), valid_labels)))
        print("Test accuracy: {:.1f}".format(accuracy(test_prediction.eval(), test_labels)))
        #test_preds[name] = test_prediction.eval().ravel()

# %%
## create a distorted image test set
## rotate each image 90 degrees counterclockwise

rotated_test_dataset = []
for i in test_dataset:
    rotated_i = np.rot90(i)
    rotated_test_dataset.append(rotated_i)
rotated_test_dataset = np.array(rotated_test_dataset)

# %%
## this code was repurposed from Week 7 Section Jupyter Notebook

image_size = 32
num_labels = 10
num_channels = 3 # RGB
batch_size = 16
patch_size = 5
depth1 = 32
depth2 = 64
num_hidden = 1024

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    #tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(rotated_test_dataset)

    # Variables.
    layer1_weights = weight_variable([patch_size, patch_size, num_channels, depth1])
    layer1_biases = bias_variable([depth1])
    layer2_weights = weight_variable([patch_size, patch_size, depth1, depth2])
    layer2_biases = bias_variable([depth2])
    layer3_weights = weight_variable([image_size // 4 * image_size // 4 * depth2, num_hidden])
    layer3_biases = bias_variable([num_hidden])
    layer4_weights = weight_variable([num_hidden, num_labels])
    layer4_biases = bias_variable([num_labels])

    keep_prob = tf.placeholder(tf.float32)
    # Model with dropout
    def model(data, proba=keep_prob):
        # Convolution
        conv1 = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME') + layer1_biases
        pooled1 = tf.nn.max_pool(tf.nn.relu(conv1), ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')
        # Convolution
        conv2 = tf.nn.conv2d(pooled1, layer2_weights, [1, 1, 1, 1], padding='SAME') + layer2_biases
        pooled2 = tf.nn.max_pool(tf.nn.relu(conv2), ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')
        # Fully Connected Layer
        shape = pooled2.get_shape().as_list()
        reshape = tf.reshape(pooled2, [shape[0], shape[1] * shape[2] * shape[3]])
        full3 = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        # Dropout
        full3 = tf.nn.dropout(full3, proba)
        return(tf.matmul(full3, layer4_weights) + layer4_biases)
  
    # Training computation.
    logits = model(tf_train_dataset, keep_prob)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

    # Optimizer.
    optimizer = tf.train.AdamOptimizer(1e-4).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    #valid_prediction = tf.nn.softmax(model(tf_valid_dataset,1.0))
    test_prediction = tf.nn.softmax(model(tf_test_dataset,1.0))

# %%
## this code was repurposed from Week 7 Section Jupyter Notebook
t0 = time.time()
run_session(100001, "CNN", 0.5)
print(time.time() - t0)
# Out:
# Initialized
# Minibatch loss at epoch 0: 2.306685209274292
# Minibatch accuracy: 0.0
# Minibatch loss at epoch 500: 1.8999409675598145
# Minibatch accuracy: 25.0
# Minibatch loss at epoch 1000: 1.8542370796203613
# Minibatch accuracy: 31.2
# Minibatch loss at epoch 1500: 1.1044995784759521
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 2000: 1.5367530584335327
# Minibatch accuracy: 56.2
# Minibatch loss at epoch 2500: 1.6072032451629639
# Minibatch accuracy: 56.2
# Minibatch loss at epoch 3000: 1.9589229822158813
# Minibatch accuracy: 31.2
# Minibatch loss at epoch 3500: 1.6274793148040771
# Minibatch accuracy: 25.0
# Minibatch loss at epoch 4000: 1.3590004444122314
# Minibatch accuracy: 56.2
# Minibatch loss at epoch 4500: 1.501413106918335
# Minibatch accuracy: 43.8
# Minibatch loss at epoch 5000: 0.9400443434715271
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 5500: 2.337679386138916
# Minibatch accuracy: 25.0
# Minibatch loss at epoch 6000: 0.9790550470352173
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 6500: 1.1426817178726196
# Minibatch accuracy: 56.2
# Minibatch loss at epoch 7000: 1.3382818698883057
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 7500: 1.2110443115234375
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 8000: 1.5214520692825317
# Minibatch accuracy: 31.2
# Minibatch loss at epoch 8500: 0.6733605265617371
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 9000: 1.0020453929901123
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 9500: 1.42529296875
# Minibatch accuracy: 56.2
# Minibatch loss at epoch 10000: 0.9047150015830994
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 10500: 1.13081693649292
# Minibatch accuracy: 56.2
# Minibatch loss at epoch 11000: 0.6109287738800049
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 11500: 1.4052894115447998
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 12000: 1.0796188116073608
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 12500: 1.004469633102417
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 13000: 1.0707236528396606
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 13500: 0.8973363637924194
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 14000: 1.116532325744629
# Minibatch accuracy: 50.0
# Minibatch loss at epoch 14500: 1.0192155838012695
# Minibatch accuracy: 50.0
# Minibatch loss at epoch 15000: 0.8056734204292297
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 15500: 1.2065249681472778
# Minibatch accuracy: 50.0
# Minibatch loss at epoch 16000: 1.4824278354644775
# Minibatch accuracy: 50.0
# Minibatch loss at epoch 16500: 0.615386962890625
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 17000: 0.7208921909332275
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 17500: 1.0013742446899414
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 18000: 0.71799635887146
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 18500: 0.6527758240699768
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 19000: 0.9282210469245911
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 19500: 0.9004929065704346
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 20000: 0.6857665777206421
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 20500: 0.7348810434341431
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 21000: 0.6674057245254517
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 21500: 0.8904123306274414
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 22000: 0.6779292821884155
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 22500: 0.8721112012863159
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 23000: 0.7558289766311646
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 23500: 0.7702072262763977
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 24000: 0.9638221859931946
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 24500: 0.811545729637146
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 25000: 0.6009457111358643
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 25500: 0.7080456614494324
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 26000: 0.525358259677887
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 26500: 0.5000316500663757
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 27000: 0.821195125579834
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 27500: 0.8328880071640015
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 28000: 0.41069889068603516
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 28500: 0.4205305874347687
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 29000: 0.5791715383529663
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 29500: 0.6438294649124146
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 30000: 0.9236534833908081
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 30500: 0.4783324897289276
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 31000: 0.5965115427970886
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 31500: 0.5417752265930176
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 32000: 0.20423664152622223
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 32500: 0.5054539442062378
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 33000: 0.6850519180297852
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 33500: 0.7006518840789795
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 34000: 0.5416436791419983
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 34500: 0.35153281688690186
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 35000: 0.4687761664390564
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 35500: 0.7606726884841919
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 36000: 0.38947081565856934
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 36500: 0.6552870273590088
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 37000: 0.3893558382987976
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 37500: 0.24134650826454163
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 38000: 0.5343644022941589
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 38500: 0.4225873649120331
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 39000: 0.16581694781780243
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 39500: 0.47851285338401794
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 40000: 0.3139435350894928
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 40500: 0.16621603071689606
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 41000: 0.5469581484794617
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 41500: 0.06930115818977356
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 42000: 0.22750771045684814
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 42500: 0.09425157308578491
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 43000: 0.5233167409896851
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 43500: 0.4803806245326996
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 44000: 0.33684083819389343
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 44500: 0.6078972220420837
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 45000: 0.2609153389930725
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 45500: 0.2957236170768738
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 46000: 0.23071105778217316
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 46500: 0.38974273204803467
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 47000: 0.19442421197891235
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 47500: 0.13147667050361633
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 48000: 0.35279580950737
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 48500: 0.5977262258529663
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 49000: 0.2896437346935272
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 49500: 0.13878336548805237
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 50000: 0.1546308845281601
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 50500: 0.1892731487751007
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 51000: 0.35546404123306274
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 51500: 0.2600775361061096
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 52000: 0.14667914807796478
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 52500: 0.14275535941123962
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 53000: 0.18964740633964539
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 53500: 0.13519763946533203
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 54000: 0.264541894197464
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 54500: 0.16616486012935638
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 55000: 0.2984159290790558
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 55500: 0.2090061902999878
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 56000: 0.06658591330051422
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 56500: 0.021638663485646248
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 57000: 0.12739256024360657
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 57500: 0.10419658571481705
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 58000: 0.11016757786273956
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 58500: 0.19678634405136108
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 59000: 0.05877368152141571
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 59500: 0.0740801990032196
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 60000: 0.09750501066446304
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 60500: 0.23546896874904633
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 61000: 0.07187096774578094
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 61500: 0.19699935615062714
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 62000: 0.01265041995793581
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 62500: 0.46904486417770386
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 63000: 0.37450647354125977
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 63500: 0.06696675717830658
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 64000: 0.10041945427656174
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 64500: 0.14054104685783386
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 65000: 0.05930810049176216
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 65500: 0.08382493257522583
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 66000: 0.1645083874464035
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 66500: 0.15323176980018616
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 67000: 0.06479045003652573
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 67500: 0.18957099318504333
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 68000: 0.06419769674539566
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 68500: 0.10577191412448883
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 69000: 0.18515223264694214
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 69500: 0.21599367260932922
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 70000: 0.11077629029750824
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 70500: 0.19179414212703705
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 71000: 0.18481124937534332
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 71500: 0.07863961905241013
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 72000: 0.05610792338848114
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 72500: 0.1635945439338684
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 73000: 0.02588670141994953
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 73500: 0.06400944292545319
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 74000: 0.17959734797477722
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 74500: 0.025782834738492966
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 75000: 0.04470641911029816
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 75500: 0.005550280213356018
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 76000: 0.08349023759365082
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 76500: 0.06437908113002777
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 77000: 0.07220952957868576
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 77500: 0.10558289289474487
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 78000: 0.06204014644026756
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 78500: 0.09112098813056946
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 79000: 0.026359084993600845
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 79500: 0.12973108887672424
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 80000: 0.09522506594657898
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 80500: 0.031578779220581055
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 81000: 0.18230625987052917
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 81500: 0.3118681311607361
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 82000: 0.16762468218803406
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 82500: 0.2512205243110657
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 83000: 0.009882299229502678
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 83500: 0.04270311817526817
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 84000: 0.0059366836212575436
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 84500: 0.15560515224933624
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 85000: 0.05192190036177635
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 85500: 0.03195785731077194
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 86000: 0.08958938717842102
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 86500: 0.05685671791434288
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 87000: 0.01499080564826727
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 87500: 0.26707616448402405
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 88000: 0.07357955724000931
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 88500: 0.057003241032361984
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 89000: 0.01582801342010498
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 89500: 0.06228107959032059
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 90000: 0.0700543224811554
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 90500: 0.12405774742364883
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 91000: 0.05265478417277336
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 91500: 0.1419852077960968
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 92000: 0.4068732261657715
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 92500: 0.14289170503616333
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 93000: 0.07563991099596024
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 93500: 0.07518287003040314
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 94000: 0.024183016270399094
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 94500: 0.03671484440565109
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 95000: 0.04019288718700409
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 95500: 0.01919243298470974
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 96000: 0.003968808799982071
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 96500: 0.019275054335594177
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 97000: 0.11845700442790985
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 97500: 0.18873167037963867
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 98000: 0.30735984444618225
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 98500: 0.1141015961766243
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 99000: 0.09653506428003311
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 99500: 0.11255104839801788
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 100000: 0.01701810583472252
# Minibatch accuracy: 100.0
# Test accuracy: 26.9
# 5650.561902046204
