# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import sys
from IPython.display import display, Image
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import OneHotEncoder
import pickle
import time
## cPicklne no worky in Python3
#from six.moves import cPickle as pickle
from six.moves import range

# Config the matlotlib backend as plotting inline in IPython
# %matplotlib inline

import tensorflow as tf

# %%
def load_CIFAR_batch(filename):
  """ load single batch of cifar """
  with open(filename, 'rb') as f:
    datadict = pickle.load(f, encoding='latin')
    X = zero_center_pixels(datadict['data'])
    Y = datadict['labels']
    X = X.reshape(10000, 3, 32, 32).transpose(0,2,3,1).astype("float32")
    Y = LabelBinarizer().fit_transform(np.array(Y)) 
    return X, Y

def load_CIFAR10(ROOT):
  """ load all of cifar """
  xs = []
  ys = []
  for b in range(1,6):
    f = os.path.join(ROOT, 'data_batch_%d' % (b, ))
    X, Y = load_CIFAR_batch(f)
    xs.append(X)
    ys.append(Y)    
  Xtr = np.concatenate(xs)
  Ytr = np.concatenate(ys)
  del X, Y
  Xte, Yte = load_CIFAR_batch(os.path.join(ROOT, 'test_batch'))
  return Xtr, Ytr, Xte, Yte

def get_CIFAR10_data(num_training=50000, num_validation=0, num_test=10000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = './cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    X_train = X_train.astype("float32").copy()
    X_val = X_val.astype("float32").copy()
    x_test = X_test.astype("float32").copy()

    return X_train, y_train, X_val, y_val, X_test, y_test

def zero_center_pixels(data):
    scale = StandardScaler().fit(data)
    old_mean = scale.mean_.astype('float32')
    old_sigma = np.sqrt(scale.var_).astype('float32')
    return (data - old_mean) * 0.5 / old_sigma
    
train_dataset, train_labels, val_dataset, val_labels, test_dataset, test_labels = get_CIFAR10_data(50000, 0, 10000)
print('Train data shape: ', train_dataset.shape)
print('Train labels shape: ', train_labels.shape)
print('Validation data shape: ', val_dataset.shape)
print('Validation labels shape: ', val_labels.shape)
print('Test data shape: ', test_dataset.shape)
print('Test labels shape: ', test_labels.shape)
# Out:
# /Users/xx/anaconda/envs/tensorflow/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/xx/anaconda/envs/tensorflow/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/xx/anaconda/envs/tensorflow/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/xx/anaconda/envs/tensorflow/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/xx/anaconda/envs/tensorflow/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/xx/anaconda/envs/tensorflow/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# Train data shape:  (50000, 32, 32, 3)
# Train labels shape:  (50000, 10)
# Validation data shape:  (0, 32, 32, 3)
# Validation labels shape:  (0, 10)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000, 10)

# %%
'''
##  this code was repurposed from Week 7 Section Jupyter Notebook
## reshaping the data to 4D Tensor 

image_size = 32
num_labels = 10
num_channels = 3 # RGB

def reformat(dataset, labels):
    dataset = dataset.reshape((-1, image_size, image_size, num_channels)).astype(np.float32)
    labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
    return(dataset, labels)

train_dataset, train_labels = reformat(train_dataset, train_labels)
#valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
#print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
''';

# %% [markdown]
# ---
# - Step 5 -
# ============
# Convolutional Neural Nets
# ---------
#
# Now we turn to building a CNN using the architecture described in the TensorFlow website tutorial [Deep MNIST for Experts](https://www.tensorflow.org/versions/r0.11/tutorials/mnist/pros/index.html). It will be a small network with two convolutional layers, followed by one fully connected layer. We'll limit the depth of this model so that it will run fine on the CPU and give a more elaborate architecture below that you can experiment with. Most production CNNs run on GPUs because they require more computation power. You can also find this example explained in Chapter 5 of [First Contact with TensorFlow](http://www.jorditorres.org/first-contact-with-tensorflow/) and in Chapter 5 of "Getting started with TensorFlow" available on [Proquest through Hollis](http://proquest.safaribooksonline.com.ezp-prod1.hul.harvard.edu/book/programming/machine-learning/9781786468574)
#
# ### Other useful references
# There are also web books: Michael A. Nielsen, [Neural Networks and Deep Learning](http://neuralnetworksanddeeplearning.com/chap6.html) and Goodfellow-et-al [Deep Learning](http://www.deeplearningbook.org/) (which is a preprint, available in HTML). There is also [Colah's blog](http://colah.github.io/) that explains convolutions and has some impressive visualizations.
#
# If you want to experiment hands-on with convolutions, then download [the GIMP](https://www.gimp.org/downloads/) (if you don't already have it), load up some of your favourite images, and then go to Filters $\rightarrow$ Generic $\rightarrow$ Convolution Matrix.
# [Here](https://docs.gimp.org/en/plug-in-convmatrix.html) are some examples.
#
# ---

# %% [markdown]
# ### Choices to make in a CNN
# * convolution kernel dimensions: the patch size (e.g. 5x5)
# * stride length: 1, 2, something else
# * the padding, SAME or VALID
# * pooling: average or max pooling, pooling size
#
#
# To make the CNN, we will use two other `nn` functions in TensorFlow. The first is for the convolution itself, called [```tf.nn.conv2d()```](https://www.tensorflow.org/versions/r0.11/api_docs/python/nn.html#conv2d) . The function takes a 4D input tensor (hence the reformatting in the previous box), the weight variable and then both the stride and padding are specified as parameters.
#
# The second function is the pooling function, either [```tf.nn.max_pool```](https://www.tensorflow.org/versions/r0.11/api_docs/python/nn.html#max_pool) or [```tf.nn.avg_pool```](https://www.tensorflow.org/versions/r0.11/api_docs/python/nn.html#avg_pool). These functions take a 4D input tensor, along with the pooling size, the stride and the padding specified as parameters. We will show max_pool in the example.
#
# Note that between the parameters in convolution and the pooling, we have accumulated a number of hyper-parameters - this gives rise to a large number of options for tuning the best performing model, even without considering regularization/dropout and fully connected layers.
#
# We redefine the weight and bias functions as per the TensorFlow example.

# %%
## this code was repurposed from Week 7 Section Jupyter Notebook

def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
            / predictions.shape[0])

def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.01)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

# %%
## this code was repurposed from Week 7 Section Jupyter Notebook

# Re-define the function to include the keep probability
def run_session(num_epochs, name, k_prob=1.0):

    with tf.Session(graph=graph) as session:
        merged = tf.merge_all_summaries()  
        writer = tf.train.SummaryWriter("/tmp/tensorflowlogs", session.graph)
        tf.initialize_all_variables().run()
        print("Initialized")
        for epoch in range(num_epochs):
            offset = (epoch * batch_size) % (train_labels.shape[0] - batch_size)
            batch_data = train_dataset[offset:(offset + batch_size), :]
            batch_labels = train_labels[offset:(offset + batch_size), :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob : k_prob}
            _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
            if (epoch % 500 == 0):
                print("Minibatch loss at epoch {}: {}".format(epoch, l))
                print("Minibatch accuracy: {:.1f}".format(accuracy(predictions, batch_labels)))
                #print("Validation accuracy: {:.1f}".format(accuracy(valid_prediction.eval(), valid_labels)))
        print("Test accuracy: {:.1f}".format(accuracy(test_prediction.eval(), test_labels)))
        #test_preds[name] = test_prediction.eval().ravel()

# %%
## this code was repurposed from Week 7 Section Jupyter Notebook

image_size = 32
num_labels = 10
num_channels = 3 # RGB
batch_size = 16
patch_size = 5
depth1 = 32
depth2 = 64
num_hidden = 1024

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    #tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    layer1_weights = weight_variable([patch_size, patch_size, num_channels, depth1])
    layer1_biases = bias_variable([depth1])
    layer2_weights = weight_variable([patch_size, patch_size, depth1, depth2])
    layer2_biases = bias_variable([depth2])
    layer3_weights = weight_variable([image_size // 4 * image_size // 4 * depth2, num_hidden])
    layer3_biases = bias_variable([num_hidden])
    layer4_weights = weight_variable([num_hidden, num_labels])
    layer4_biases = bias_variable([num_labels])

    keep_prob = tf.placeholder(tf.float32)
    # Model with dropout
    def model(data, proba=keep_prob):
        # Convolution
        conv1 = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME') + layer1_biases
        pooled1 = tf.nn.max_pool(tf.nn.relu(conv1), ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')
        # Convolution
        conv2 = tf.nn.conv2d(pooled1, layer2_weights, [1, 1, 1, 1], padding='SAME') + layer2_biases
        pooled2 = tf.nn.max_pool(tf.nn.relu(conv2), ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')
        # Fully Connected Layer
        shape = pooled2.get_shape().as_list()
        reshape = tf.reshape(pooled2, [shape[0], shape[1] * shape[2] * shape[3]])
        full3 = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        # Dropout
        full3 = tf.nn.dropout(full3, proba)
        return(tf.matmul(full3, layer4_weights) + layer4_biases)
  
    # Training computation.
    logits = model(tf_train_dataset, keep_prob)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

    # Optimizer.
    optimizer = tf.train.AdamOptimizer(1e-4).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    #valid_prediction = tf.nn.softmax(model(tf_valid_dataset,1.0))
    test_prediction = tf.nn.softmax(model(tf_test_dataset,1.0))

# %%
## this code was repurposed from Week 7 Section Jupyter Notebook
t0 = time.time()
run_session(100001, "CNN", 0.5)
print(time.time() - t0)
# Out:
# Initialized
# Minibatch loss at epoch 0: 2.3145790100097656
# Minibatch accuracy: 12.5
# Minibatch loss at epoch 500: 1.8666150569915771
# Minibatch accuracy: 31.2
# Minibatch loss at epoch 1000: 1.9912878274917603
# Minibatch accuracy: 18.8
# Minibatch loss at epoch 1500: 0.9957470893859863
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 2000: 1.506471872329712
# Minibatch accuracy: 37.5
# Minibatch loss at epoch 2500: 1.5016636848449707
# Minibatch accuracy: 37.5
# Minibatch loss at epoch 3000: 1.9718449115753174
# Minibatch accuracy: 31.2
# Minibatch loss at epoch 3500: 1.8194414377212524
# Minibatch accuracy: 12.5
# Minibatch loss at epoch 4000: 1.2798545360565186
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 4500: 1.5744123458862305
# Minibatch accuracy: 43.8
# Minibatch loss at epoch 5000: 0.8924976587295532
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 5500: 1.9213392734527588
# Minibatch accuracy: 31.2
# Minibatch loss at epoch 6000: 0.873744785785675
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 6500: 1.0028324127197266
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 7000: 1.3455607891082764
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 7500: 1.2337498664855957
# Minibatch accuracy: 56.2
# Minibatch loss at epoch 8000: 1.4525989294052124
# Minibatch accuracy: 43.8
# Minibatch loss at epoch 8500: 0.7230203151702881
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 9000: 0.9569737911224365
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 9500: 1.254827857017517
# Minibatch accuracy: 43.8
# Minibatch loss at epoch 10000: 1.0978472232818604
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 10500: 0.8880171179771423
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 11000: 0.6010226607322693
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 11500: 1.4061214923858643
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 12000: 1.1131267547607422
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 12500: 0.7870467901229858
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 13000: 1.2431141138076782
# Minibatch accuracy: 50.0
# Minibatch loss at epoch 13500: 0.8444684147834778
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 14000: 1.2210053205490112
# Minibatch accuracy: 50.0
# Minibatch loss at epoch 14500: 1.1484925746917725
# Minibatch accuracy: 56.2
# Minibatch loss at epoch 15000: 0.8126317262649536
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 15500: 1.3357114791870117
# Minibatch accuracy: 50.0
# Minibatch loss at epoch 16000: 1.2612643241882324
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 16500: 0.36712855100631714
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 17000: 0.8306191563606262
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 17500: 0.6671473979949951
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 18000: 0.6920841336250305
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 18500: 0.672356367111206
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 19000: 0.9885218143463135
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 19500: 1.0723989009857178
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 20000: 0.700957179069519
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 20500: 0.8506489396095276
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 21000: 0.5113439559936523
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 21500: 0.9639536738395691
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 22000: 0.6220768690109253
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 22500: 0.7085772752761841
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 23000: 0.6425759792327881
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 23500: 1.2100086212158203
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 24000: 0.9415435791015625
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 24500: 0.9503380656242371
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 25000: 0.9169589877128601
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 25500: 0.6935057640075684
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 26000: 0.6702611446380615
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 26500: 0.6192879676818848
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 27000: 0.7858821153640747
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 27500: 1.0652968883514404
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 28000: 0.4289833903312683
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 28500: 0.5120493769645691
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 29000: 0.545683741569519
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 29500: 0.5110463500022888
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 30000: 0.9365681409835815
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 30500: 0.3685620427131653
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 31000: 0.5004201531410217
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 31500: 0.7794659733772278
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 32000: 0.341607004404068
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 32500: 0.6643169522285461
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 33000: 0.38216012716293335
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 33500: 0.48233455419540405
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 34000: 0.32032978534698486
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 34500: 0.382493257522583
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 35000: 0.6839889287948608
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 35500: 0.6209554076194763
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 36000: 0.47222065925598145
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 36500: 0.4310120940208435
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 37000: 0.2985532879829407
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 37500: 0.3380286991596222
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 38000: 0.6763359308242798
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 38500: 0.289718896150589
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 39000: 0.171896830201149
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 39500: 0.7402403354644775
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 40000: 0.3262297511100769
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 40500: 0.0808081179857254
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 41000: 0.5109221935272217
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 41500: 0.4547708034515381
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 42000: 0.5237751007080078
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 42500: 0.09692008793354034
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 43000: 0.6259401440620422
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 43500: 0.1321047693490982
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 44000: 0.3335859179496765
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 44500: 0.24698977172374725
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 45000: 0.39768022298812866
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 45500: 0.21913635730743408
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 46000: 0.2100372612476349
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 46500: 0.41003578901290894
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 47000: 0.08329467475414276
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 47500: 0.31944742798805237
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 48000: 0.16964450478553772
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 48500: 0.5251572132110596
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 49000: 0.1866982877254486
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 49500: 0.18993401527404785
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 50000: 0.2679722011089325
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 50500: 0.2567494809627533
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 51000: 0.07991007715463638
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 51500: 0.5007324814796448
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 52000: 0.13943703472614288
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 52500: 0.36927443742752075
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 53000: 0.1797560751438141
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 53500: 0.10229434818029404
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 54000: 0.15941116213798523
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 54500: 0.43201732635498047
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 55000: 0.3174937665462494
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 55500: 0.13828113675117493
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 56000: 0.14200136065483093
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 56500: 0.1205468401312828
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 57000: 0.5319947004318237
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 57500: 0.24963827431201935
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 58000: 0.08641184866428375
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 58500: 0.2224947214126587
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 59000: 0.08034582436084747
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 59500: 0.18377812206745148
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 60000: 0.4196946918964386
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 60500: 0.12638089060783386
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 61000: 0.12553678452968597
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 61500: 0.0823308527469635
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 62000: 0.1703404039144516
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 62500: 0.07237941771745682
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 63000: 0.07715097069740295
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 63500: 0.08715102821588516
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 64000: 0.08834358304738998
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 64500: 0.3956194221973419
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 65000: 0.07059338688850403
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 65500: 0.09982623159885406
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 66000: 0.40962663292884827
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 66500: 0.11885480582714081
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 67000: 0.14266902208328247
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 67500: 0.16807404160499573
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 68000: 0.06408029049634933
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 68500: 0.036165326833724976
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 69000: 0.08406540751457214
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 69500: 0.020685384050011635
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 70000: 0.04931811988353729
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 70500: 0.12848268449306488
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 71000: 0.25239261984825134
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 71500: 0.4685296416282654
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 72000: 0.035106003284454346
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 72500: 0.036004409193992615
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 73000: 0.04582655429840088
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 73500: 0.038788676261901855
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 74000: 0.07307837903499603
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 74500: 0.15585440397262573
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 75000: 0.27201271057128906
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 75500: 0.011927691288292408
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 76000: 0.11964179575443268
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 76500: 0.05950716882944107
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 77000: 0.5944364666938782
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 77500: 0.029329106211662292
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 78000: 0.2717486619949341
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 78500: 0.08217207342386246
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 79000: 0.11118535697460175
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 79500: 0.04864189401268959
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 80000: 0.2915569245815277
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 80500: 0.08748585730791092
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 81000: 0.11081749200820923
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 81500: 0.11958984285593033
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 82000: 0.07741811126470566
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 82500: 0.033458150923252106
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 83000: 0.03588221222162247
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 83500: 0.07977846264839172
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 84000: 0.03928700461983681
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 84500: 0.3195863962173462
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 85000: 0.19443485140800476
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 85500: 0.01994076371192932
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 86000: 0.17407406866550446
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 86500: 0.05877549946308136
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 87000: 0.01557831559330225
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 87500: 0.05559590831398964
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 88000: 0.033466096967458725
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 88500: 0.27507370710372925
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 89000: 0.013881776481866837
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 89500: 0.15317238867282867
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 90000: 0.07655046880245209
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 90500: 0.004369703121483326
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 91000: 0.022676270455121994
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 91500: 0.021055877208709717
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 92000: 0.010236239992082119
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 92500: 0.17119988799095154
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 93000: 0.003886596532538533
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 93500: 0.07488641142845154
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 94000: 0.07542305439710617
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 94500: 0.06856369972229004
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 95000: 0.04008530080318451
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 95500: 0.02653743326663971
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 96000: 0.029184043407440186
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 96500: 0.004573853220790625
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 97000: 0.0729609951376915
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 97500: 0.003374810330569744
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 98000: 0.17906343936920166
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 98500: 0.037440959364175797
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 99000: 0.037859734147787094
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 99500: 0.0403708815574646
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 100000: 0.03661482781171799
# Minibatch accuracy: 100.0
# Test accuracy: 73.3
# 7148.129632234573
