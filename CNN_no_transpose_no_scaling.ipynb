# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, auc

import pickle
import time

import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf

# %%
## function to read in the batch files
def unpickle(file):
    fo = open(file, 'rb')
    dict = pickle.load(fo, encoding='latin') # encoding latin otherwise no worky
    fo.close()
    return(dict)

# %%
def zero_center_pixels(data):
    scale = StandardScaler().fit(data)
    old_mean = scale.mean_.astype('float32')
    old_sigma = np.sqrt(scale.var_).astype('float32')
    return((data - old_mean) * 0.5 / old_sigma)

# %%
## read in the data
## manually is easy
data_batch_1 = unpickle('cifar-10-batches-py/data_batch_1')
data_batch_2 = unpickle('cifar-10-batches-py/data_batch_2')
data_batch_3 = unpickle('cifar-10-batches-py/data_batch_3')
data_batch_4 = unpickle('cifar-10-batches-py/data_batch_4')
data_batch_5 = unpickle('cifar-10-batches-py/data_batch_5')
test_batch = unpickle('cifar-10-batches-py/test_batch')
label_map = unpickle('cifar-10-batches-py/batches.meta')

# %%
## stack up the data batches

## stack up the data batches
all_data = []

for i in data_batch_1['data']:
    all_data.append(i)
    
for i in data_batch_2['data']:
    all_data.append(i)

for i in data_batch_3['data']:
    all_data.append(i)

for i in data_batch_4['data']:
    all_data.append(i)
    
for i in data_batch_5['data']:
    all_data.append(i)

all_data = np.array(all_data)
print(all_data.shape)
# Out:
# (50000, 3072)

# %%
## stack up the label data
all_labels = data_batch_1['labels'] + data_batch_2['labels'] + data_batch_3['labels'] + data_batch_4['labels'] + data_batch_5['labels']
all_labels = np.array(all_labels)

test_labels = np.array(test_batch['labels'])

print(all_labels.shape)
print(test_labels.shape)
# Out:
# (50000,)
# (10000,)

# %%
## scale and reshape the image data
all_data_rgb = all_data.reshape(50000, 32, 32, 3).astype('float32')
test_data_rgb = test_batch['data'].reshape(10000, 32, 32, 3).astype('float32')

# %%
train_dataset = np.array(all_data_rgb)
train_labels = np.array(LabelBinarizer().fit_transform(all_labels))
test_dataset = np.array(test_data_rgb)
test_labels = np.array(LabelBinarizer().fit_transform(test_labels))
print('Train data shape: ', train_dataset.shape)
print('Train labels shape: ', train_labels.shape)
print('Test data shape: ', test_dataset.shape)
print('Test labels shape: ', test_labels.shape)
# Out:
# Train data shape:  (50000, 32, 32, 3)
# Train labels shape:  (50000, 10)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000, 10)

# %% [markdown]
# ---
# - Step 5 -
# ============
# Convolutional Neural Nets
# ---------
#
# Now we turn to building a CNN using the architecture described in the TensorFlow website tutorial [Deep MNIST for Experts](https://www.tensorflow.org/versions/r0.11/tutorials/mnist/pros/index.html). It will be a small network with two convolutional layers, followed by one fully connected layer. We'll limit the depth of this model so that it will run fine on the CPU and give a more elaborate architecture below that you can experiment with. Most production CNNs run on GPUs because they require more computation power. You can also find this example explained in Chapter 5 of [First Contact with TensorFlow](http://www.jorditorres.org/first-contact-with-tensorflow/) and in Chapter 5 of "Getting started with TensorFlow" available on [Proquest through Hollis](http://proquest.safaribooksonline.com.ezp-prod1.hul.harvard.edu/book/programming/machine-learning/9781786468574)
#
# ### Other useful references
# There are also web books: Michael A. Nielsen, [Neural Networks and Deep Learning](http://neuralnetworksanddeeplearning.com/chap6.html) and Goodfellow-et-al [Deep Learning](http://www.deeplearningbook.org/) (which is a preprint, available in HTML). There is also [Colah's blog](http://colah.github.io/) that explains convolutions and has some impressive visualizations.
#
# If you want to experiment hands-on with convolutions, then download [the GIMP](https://www.gimp.org/downloads/) (if you don't already have it), load up some of your favourite images, and then go to Filters $\rightarrow$ Generic $\rightarrow$ Convolution Matrix.
# [Here](https://docs.gimp.org/en/plug-in-convmatrix.html) are some examples.
#
# ---

# %% [markdown]
# ### Choices to make in a CNN
# * convolution kernel dimensions: the patch size (e.g. 5x5)
# * stride length: 1, 2, something else
# * the padding, SAME or VALID
# * pooling: average or max pooling, pooling size
#
#
# To make the CNN, we will use two other `nn` functions in TensorFlow. The first is for the convolution itself, called [```tf.nn.conv2d()```](https://www.tensorflow.org/versions/r0.11/api_docs/python/nn.html#conv2d) . The function takes a 4D input tensor (hence the reformatting in the previous box), the weight variable and then both the stride and padding are specified as parameters.
#
# The second function is the pooling function, either [```tf.nn.max_pool```](https://www.tensorflow.org/versions/r0.11/api_docs/python/nn.html#max_pool) or [```tf.nn.avg_pool```](https://www.tensorflow.org/versions/r0.11/api_docs/python/nn.html#avg_pool). These functions take a 4D input tensor, along with the pooling size, the stride and the padding specified as parameters. We will show max_pool in the example.
#
# Note that between the parameters in convolution and the pooling, we have accumulated a number of hyper-parameters - this gives rise to a large number of options for tuning the best performing model, even without considering regularization/dropout and fully connected layers.
#
# We redefine the weight and bias functions as per the TensorFlow example.

# %%
## this code was repurposed from Week 7 Section Jupyter Notebook

def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
            / predictions.shape[0])

def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.01)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

# %%
## this code was repurposed from Week 7 Section Jupyter Notebook

# Re-define the function to include the keep probability
def run_session(num_epochs, name, k_prob=1.0):

    with tf.Session(graph=graph) as session:
        merged = tf.merge_all_summaries()  
        writer = tf.train.SummaryWriter("/tmp/tensorflowlogs", session.graph)
        tf.initialize_all_variables().run()
        print("Initialized")
        for epoch in range(num_epochs):
            offset = (epoch * batch_size) % (train_labels.shape[0] - batch_size)
            batch_data = train_dataset[offset:(offset + batch_size), :]
            batch_labels = train_labels[offset:(offset + batch_size), :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob : k_prob}
            _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
            if (epoch % 500 == 0):
                print("Minibatch loss at epoch {}: {}".format(epoch, l))
                print("Minibatch accuracy: {:.1f}".format(accuracy(predictions, batch_labels)))
                #print("Validation accuracy: {:.1f}".format(accuracy(valid_prediction.eval(), valid_labels)))
        print("Test accuracy: {:.1f}".format(accuracy(test_prediction.eval(), test_labels)))
        #test_preds[name] = test_prediction.eval().ravel()

# %%
## this code was repurposed from Week 7 Section Jupyter Notebook

image_size = 32
num_labels = 10
num_channels = 3 # RGB
batch_size = 16
patch_size = 5
depth1 = 32
depth2 = 64
num_hidden = 1024

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    #tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    layer1_weights = weight_variable([patch_size, patch_size, num_channels, depth1])
    layer1_biases = bias_variable([depth1])
    layer2_weights = weight_variable([patch_size, patch_size, depth1, depth2])
    layer2_biases = bias_variable([depth2])
    layer3_weights = weight_variable([image_size // 4 * image_size // 4 * depth2, num_hidden])
    layer3_biases = bias_variable([num_hidden])
    layer4_weights = weight_variable([num_hidden, num_labels])
    layer4_biases = bias_variable([num_labels])

    keep_prob = tf.placeholder(tf.float32)
    # Model with dropout
    def model(data, proba=keep_prob):
        # Convolution
        conv1 = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME') + layer1_biases
        pooled1 = tf.nn.max_pool(tf.nn.relu(conv1), ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')
        # Convolution
        conv2 = tf.nn.conv2d(pooled1, layer2_weights, [1, 1, 1, 1], padding='SAME') + layer2_biases
        pooled2 = tf.nn.max_pool(tf.nn.relu(conv2), ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')
        # Fully Connected Layer
        shape = pooled2.get_shape().as_list()
        reshape = tf.reshape(pooled2, [shape[0], shape[1] * shape[2] * shape[3]])
        full3 = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        # Dropout
        full3 = tf.nn.dropout(full3, proba)
        return(tf.matmul(full3, layer4_weights) + layer4_biases)
  
    # Training computation.
    logits = model(tf_train_dataset, keep_prob)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

    # Optimizer.
    optimizer = tf.train.AdamOptimizer(1e-4).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    #valid_prediction = tf.nn.softmax(model(tf_valid_dataset,1.0))
    test_prediction = tf.nn.softmax(model(tf_test_dataset,1.0))

# %%
## this code was repurposed from Week 7 Section Jupyter Notebook
t0 = time.time()
run_session(100001, "CNN", 0.5)
print(time.time() - t0)
# Out:
# Initialized
# Minibatch loss at epoch 0: 2.4743692874908447
# Minibatch accuracy: 0.0
# Minibatch loss at epoch 500: 1.9048080444335938
# Minibatch accuracy: 31.2
# Minibatch loss at epoch 1000: 1.8095780611038208
# Minibatch accuracy: 37.5
# Minibatch loss at epoch 1500: 0.8746853470802307
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 2000: 1.5858678817749023
# Minibatch accuracy: 31.2
# Minibatch loss at epoch 2500: 1.5046074390411377
# Minibatch accuracy: 43.8
# Minibatch loss at epoch 3000: 1.9305773973464966
# Minibatch accuracy: 31.2
# Minibatch loss at epoch 3500: 2.207211971282959
# Minibatch accuracy: 0.0
# Minibatch loss at epoch 4000: 1.7641828060150146
# Minibatch accuracy: 37.5
# Minibatch loss at epoch 4500: 1.5185484886169434
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 5000: 0.585370659828186
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 5500: 2.4030704498291016
# Minibatch accuracy: 31.2
# Minibatch loss at epoch 6000: 1.110968828201294
# Minibatch accuracy: 50.0
# Minibatch loss at epoch 6500: 0.7786077260971069
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 7000: 1.2193474769592285
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 7500: 1.267521858215332
# Minibatch accuracy: 56.2
# Minibatch loss at epoch 8000: 1.333052635192871
# Minibatch accuracy: 43.8
# Minibatch loss at epoch 8500: 0.550566554069519
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 9000: 0.9381862878799438
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 9500: 1.2283719778060913
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 10000: 0.8703676462173462
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 10500: 0.8312807083129883
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 11000: 0.3987569212913513
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 11500: 1.507015347480774
# Minibatch accuracy: 43.8
# Minibatch loss at epoch 12000: 1.1606125831604004
# Minibatch accuracy: 50.0
# Minibatch loss at epoch 12500: 1.0570218563079834
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 13000: 0.8275936245918274
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 13500: 0.7846037149429321
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 14000: 1.0420536994934082
# Minibatch accuracy: 43.8
# Minibatch loss at epoch 14500: 0.9577633142471313
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 15000: 0.7892630100250244
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 15500: 0.6822176575660706
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 16000: 1.1781678199768066
# Minibatch accuracy: 43.8
# Minibatch loss at epoch 16500: 0.579614520072937
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 17000: 0.5396414399147034
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 17500: 0.4974568486213684
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 18000: 0.5703426599502563
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 18500: 0.5794242024421692
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 19000: 0.8312736749649048
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 19500: 0.9589797258377075
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 20000: 0.7483603954315186
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 20500: 0.46661460399627686
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 21000: 0.6626229882240295
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 21500: 0.4039486050605774
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 22000: 0.5992996692657471
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 22500: 0.373933881521225
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 23000: 0.7159327268600464
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 23500: 0.8046116828918457
# Minibatch accuracy: 62.5
# Minibatch loss at epoch 24000: 0.3947199881076813
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 24500: 0.6701691150665283
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 25000: 0.25712472200393677
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 25500: 0.33867913484573364
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 26000: 0.4130626320838928
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 26500: 0.447696715593338
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 27000: 0.7571752071380615
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 27500: 0.8874340057373047
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 28000: 0.4516788125038147
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 28500: 0.27225157618522644
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 29000: 0.2646220922470093
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 29500: 0.45148640871047974
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 30000: 0.512040376663208
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 30500: 0.1573353111743927
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 31000: 0.18863725662231445
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 31500: 0.6566978096961975
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 32000: 0.3688351511955261
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 32500: 0.18859736621379852
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 33000: 0.4713784158229828
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 33500: 0.4213674068450928
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 34000: 0.1337428092956543
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 34500: 0.0595959834754467
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 35000: 0.8578897714614868
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 35500: 0.642059862613678
# Minibatch accuracy: 75.0
# Minibatch loss at epoch 36000: 0.312551885843277
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 36500: 0.5818656086921692
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 37000: 0.15083667635917664
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 37500: 0.1298605054616928
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 38000: 0.4091189503669739
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 38500: 0.49049055576324463
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 39000: 0.5620280504226685
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 39500: 0.226254403591156
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 40000: 0.22484958171844482
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 40500: 0.18813402950763702
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 41000: 0.26202914118766785
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 41500: 0.024073369801044464
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 42000: 0.48457494378089905
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 42500: 0.17759451270103455
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 43000: 0.21961352229118347
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 43500: 0.06292058527469635
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 44000: 0.5961989760398865
# Minibatch accuracy: 68.8
# Minibatch loss at epoch 44500: 0.10697206109762192
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 45000: 0.2891963720321655
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 45500: 0.3319518268108368
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 46000: 0.04659125208854675
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 46500: 0.04335697740316391
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 47000: 0.036588121205568314
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 47500: 0.6401709318161011
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 48000: 0.4694398045539856
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 48500: 0.22622182965278625
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 49000: 0.04756424203515053
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 49500: 0.11422668397426605
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 50000: 0.1636672168970108
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 50500: 0.4021591544151306
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 51000: 0.17635226249694824
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 51500: 0.1472419947385788
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 52000: 0.21134603023529053
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 52500: 0.11211573332548141
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 53000: 0.19633501768112183
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 53500: 0.045298609882593155
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 54000: 0.416454553604126
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 54500: 0.10375154763460159
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 55000: 0.10813260078430176
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 55500: 0.07183761894702911
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 56000: 0.0571926049888134
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 56500: 0.026799164712429047
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 57000: 0.20642316341400146
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 57500: 0.12271062284708023
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 58000: 0.011524890549480915
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 58500: 0.49524497985839844
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 59000: 0.12981539964675903
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 59500: 0.13552162051200867
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 60000: 0.030680768191814423
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 60500: 0.05366569012403488
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 61000: 0.04340868070721626
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 61500: 0.1777363270521164
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 62000: 0.049641963094472885
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 62500: 0.01091165654361248
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 63000: 0.38962647318840027
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 63500: 0.33263280987739563
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 64000: 0.12936921417713165
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 64500: 0.3289243280887604
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 65000: 0.10058369487524033
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 65500: 0.17397929728031158
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 66000: 0.00901058316230774
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 66500: 0.5664168000221252
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 67000: 0.05739068239927292
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 67500: 0.005598973482847214
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 68000: 0.09100955724716187
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 68500: 0.0337383896112442
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 69000: 0.054262466728687286
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 69500: 0.01875031180679798
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 70000: 0.026864342391490936
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 70500: 0.37012603878974915
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 71000: 0.3164141774177551
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 71500: 0.034844838082790375
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 72000: 0.42379552125930786
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 72500: 0.0046044387854635715
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 73000: 0.4146779477596283
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 73500: 0.06134317070245743
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 74000: 0.007033240050077438
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 74500: 0.046320851892232895
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 75000: 0.1310996413230896
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 75500: 0.3046588897705078
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 76000: 0.0914047583937645
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 76500: 0.13607224822044373
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 77000: 0.04288475215435028
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 77500: 0.08700837939977646
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 78000: 0.10920412838459015
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 78500: 0.3839034140110016
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 79000: 0.890589714050293
# Minibatch accuracy: 81.2
# Minibatch loss at epoch 79500: 0.4441016912460327
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 80000: 0.34890955686569214
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 80500: 0.012760080397129059
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 81000: 0.00378043157979846
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 81500: 0.05034325644373894
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 82000: 0.10873226821422577
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 82500: 0.04750856012105942
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 83000: 0.023238439112901688
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 83500: 0.30372363328933716
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 84000: 0.1319953352212906
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 84500: 0.23278522491455078
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 85000: 0.07737154513597488
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 85500: 0.09649811685085297
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 86000: 0.08993612974882126
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 86500: 0.025587979704141617
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 87000: 0.14408138394355774
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 87500: 0.017736777663230896
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 88000: 0.2990107834339142
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 88500: 0.262586772441864
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 89000: 0.20232464373111725
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 89500: 0.18847161531448364
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 90000: 0.038634322583675385
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 90500: 0.000726876372937113
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 91000: 0.21080747246742249
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 91500: 0.07669233530759811
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 92000: 0.004676546435803175
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 92500: 0.170552060008049
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 93000: 0.060386959463357925
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 93500: 0.041854068636894226
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 94000: 0.10828177630901337
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 94500: 0.18028484284877777
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 95000: 0.00386150274425745
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 95500: 0.04304548352956772
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 96000: 0.016694264486432076
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 96500: 0.0671268105506897
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 97000: 0.015420298092067242
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 97500: 0.21541817486286163
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 98000: 0.008066823706030846
# Minibatch accuracy: 100.0
# Minibatch loss at epoch 98500: 0.1557900607585907
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 99000: 0.23636624217033386
# Minibatch accuracy: 87.5
# Minibatch loss at epoch 99500: 0.5431707501411438
# Minibatch accuracy: 93.8
# Minibatch loss at epoch 100000: 0.3314459025859833
# Minibatch accuracy: 93.8
# Test accuracy: 63.2
# 12856.39557313919
